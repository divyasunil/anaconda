# %%
import pandas as pd

# %%
customer=pd.read_csv("Customer.csv")

# %%
customer
# Out:
#     Index First Name   Last Name                        Company  \
# 0       1      Frank  Villarreal       Craig, Dennis and Maddox
# 1       2     Gloria       Lopez                Jacobs and Sons
# 2       3      April      Guerra                      Price PLC
# 3       4       Anne       Dixon                  Chambers-Cruz
# 4       5    Latasha   Fernandez                   Townsend LLC
# 5       6       Kirk  Strickland                Brewer-Thompson
# 6       7     Shelly      Ingram    Braun, Fernandez and Jacobs
# 7       8    Clayton     Maxwell                    Smith-Munoz
# 8       9      Tammy     Kaufman          Mayer, Bowen and Rowe
# 9      10    Deborah      Dunlap          Choi, Rush and Larsen
# 10     11         Jo      Clarke        Dalton, Welch and Beard
# 11     12     Eugene     Cabrera                Watkins-Shields
# 12     13    Mallory   Stevenson    Hill, Livingston and Lozano
# 13     14       Tami      Rogers       Robles, Shaw and Herring
# ...

# %%
customer.head(2)
# Out:
#    Index First Name   Last Name                   Company         City  \
# 0      1      Frank  Villarreal  Craig, Dennis and Maddox     Reidtown
# 1      2     Gloria       Lopez           Jacobs and Sons  East Judith
#
#    Country
# 0   Panama
# 1  Nigeria

# %%
customer['First Name']
# Out:
# 0        Frank
# 1       Gloria
# 2        April
# 3         Anne
# 4      Latasha
# 5         Kirk
# 6       Shelly
# 7      Clayton
# 8        Tammy
# 9      Deborah
# 10          Jo
# 11      Eugene
# 12     Mallory
# 13        Tami
# 14    Terrance
# 15       Tommy
# 16     Brianna
# 17      Claire
# 18       Leroy
# 19        Seth
# 20    Lawrence
# 21     Natasha
# 22       Angie
# 23     Spencer
# 24       Lacey
# 25     Tristan
# 26       Helen
# 27        Mary
# 28         Amy
# 29      Alfred
# 30        Carl
# 31       Carly
# 32      Shelly
# 33         Zoe
# 34         Ana
# 35        Adam
# 36    Kimberly
# 37     Rebecca
# 38      Teresa
# 39      Julian
# 40      Alfred
# 41      Melody
# 42    Courtney
# 43     Bradley
# 44      Shelby
# 45      Alison
# 46       Andre
# 47        Jody
# 48       Lance
# 49         Sue
# Name: First Name, dtype: object

# %%
customer['Company']
# Out:
# 0          Craig, Dennis and Maddox
# 1                   Jacobs and Sons
# 2                         Price PLC
# 3                     Chambers-Cruz
# 4                      Townsend LLC
# 5                   Brewer-Thompson
# 6       Braun, Fernandez and Jacobs
# 7                       Smith-Munoz
# 8             Mayer, Bowen and Rowe
# 9             Choi, Rush and Larsen
# 10          Dalton, Welch and Beard
# 11                  Watkins-Shields
# 12      Hill, Livingston and Lozano
# 13         Robles, Shaw and Herring
# 14                    Rios and Sons
# 15       Middleton, Roach and Cohen
# 16      Mendez, Bell and Fitzgerald
# 17      Singh, Carroll and Richards
# 18        Haney, Manning and Steele
# 19         Hoover, Johnson and Boyd
# 20                     Larsen-Green
# 21         Haas, Levine and Burnett
# 22          Luna, Mack and Copeland
# 23                        Kelly PLC
# 24                     Patel-Turner
# 25                     Santana-Roth
# ...

# %%
customer['Company'].unique()
# Out:
# array(['Craig, Dennis and Maddox', 'Jacobs and Sons', 'Price PLC',
#        'Chambers-Cruz', 'Townsend LLC', 'Brewer-Thompson',
#        'Braun, Fernandez and Jacobs', 'Smith-Munoz',
#        'Mayer, Bowen and Rowe', 'Choi, Rush and Larsen',
#        'Dalton, Welch and Beard', 'Watkins-Shields',
#        'Hill, Livingston and Lozano', 'Robles, Shaw and Herring',
#        'Rios and Sons', 'Middleton, Roach and Cohen',
#        'Mendez, Bell and Fitzgerald', 'Singh, Carroll and Richards',
#        'Haney, Manning and Steele', 'Hoover, Johnson and Boyd',
#        'Larsen-Green', 'Haas, Levine and Burnett',
#        'Luna, Mack and Copeland', 'Kelly PLC', 'Patel-Turner',
#        'Santana-Roth', 'Conrad PLC', 'Donovan-Lewis',
#        'Ballard, Branch and Bullock', 'Carroll, Haley and Graham',
#        'Mack and Sons', 'Garrett, Shaw and Patrick',
#        'Mccullough, Castillo and Hahn', 'Ware Ltd', 'Villa-Frost',
#        'Elliott, Hoffman and Martin', 'Johns-Howell',
# ...

# %%
customer.iloc[3]
# Out:
# Index                       4
# First Name               Anne
# Last Name               Dixon
# Company         Chambers-Cruz
# City          West Tanyamouth
# Country          Cook Islands
# Name: 3, dtype: object

# %%
customer[3:4]
# Out:
#    Index First Name Last Name        Company             City       Country
# 3      4       Anne     Dixon  Chambers-Cruz  West Tanyamouth  Cook Islands

# %%
customer.tail()
# Out:
#     Index First Name Last Name                   Company             City  \
# 45     46     Alison  Matthews    Terry, Morrow and Chan  North Erikafort
# 46     47      Andre      Bray            Powers-Mahoney         Kurtland
# 47     48       Jody    Daniel                  Wolf Ltd        Lake Luis
# 48     49      Lance      Haas  Hall, Sherman and Nguyen       Boyerville
# 49     50        Sue      Moon           Rasmussen Group      South Ralph
#
#      Country
# 45    Taiwan
# 46   Tokelau
# 47  Slovenia
# 48  Bulgaria
# 49     Korea

# %%
customer.head()
# Out:
#    Index First Name   Last Name                   Company             City  \
# 0      1      Frank  Villarreal  Craig, Dennis and Maddox         Reidtown
# 1      2     Gloria       Lopez           Jacobs and Sons      East Judith
# 2      3      April      Guerra                 Price PLC    Davidsonmouth
# 3      4       Anne       Dixon             Chambers-Cruz  West Tanyamouth
# 4      5    Latasha   Fernandez              Townsend LLC         Seanport
#
#              Country
# 0             Panama
# 1            Nigeria
# 2  Brunei Darussalam
# 3       Cook Islands
# 4            Germany

# %%
customer[customer['Country']=='Germany']
# Out:
#    Index First Name  Last Name       Company      City  Country
# 4      5    Latasha  Fernandez  Townsend LLC  Seanport  Germany

# %% [raw]
# customer=pd.read_csv("Customer.csv")

# %%
customer
# Out:
#     Index First Name   Last Name                        Company  \
# 0       1      Frank  Villarreal       Craig, Dennis and Maddox
# 1       2     Gloria       Lopez                Jacobs and Sons
# 2       3      April      Guerra                      Price PLC
# 3       4       Anne       Dixon                  Chambers-Cruz
# 4       5    Latasha   Fernandez                   Townsend LLC
# 5       6       Kirk  Strickland                Brewer-Thompson
# 6       7     Shelly      Ingram    Braun, Fernandez and Jacobs
# 7       8    Clayton     Maxwell                    Smith-Munoz
# 8       9      Tammy     Kaufman          Mayer, Bowen and Rowe
# 9      10    Deborah      Dunlap          Choi, Rush and Larsen
# 10     11         Jo      Clarke        Dalton, Welch and Beard
# 11     12     Eugene     Cabrera                Watkins-Shields
# 12     13    Mallory   Stevenson    Hill, Livingston and Lozano
# 13     14       Tami      Rogers       Robles, Shaw and Herring
# ...

# %%
customer[customer['Index']>5]
# Out:
#     Index First Name   Last Name                        Company  \
# 5       6       Kirk  Strickland                Brewer-Thompson
# 6       7     Shelly      Ingram    Braun, Fernandez and Jacobs
# 7       8    Clayton     Maxwell                    Smith-Munoz
# 8       9      Tammy     Kaufman          Mayer, Bowen and Rowe
# 9      10    Deborah      Dunlap          Choi, Rush and Larsen
# 10     11         Jo      Clarke        Dalton, Welch and Beard
# 11     12     Eugene     Cabrera                Watkins-Shields
# 12     13    Mallory   Stevenson    Hill, Livingston and Lozano
# 13     14       Tami      Rogers       Robles, Shaw and Herring
# 14     15   Terrance       Quinn                  Rios and Sons
# 15     16      Tommy      Ingram     Middleton, Roach and Cohen
# 16     17    Brianna    Petersen    Mendez, Bell and Fitzgerald
# 17     18     Claire     Ferrell    Singh, Carroll and Richards
# 18     19      Leroy      Hunter      Haney, Manning and Steele
# ...

# %%
customer[customer['Index']<=4]
# Out:
#    Index First Name   Last Name                   Company             City  \
# 0      1      Frank  Villarreal  Craig, Dennis and Maddox         Reidtown
# 1      2     Gloria       Lopez           Jacobs and Sons      East Judith
# 2      3      April      Guerra                 Price PLC    Davidsonmouth
# 3      4       Anne       Dixon             Chambers-Cruz  West Tanyamouth
#
#              Country
# 0             Panama
# 1            Nigeria
# 2  Brunei Darussalam
# 3       Cook Islands

# %%
customer[customer['Index']>5].head()
# Out:
#    Index First Name   Last Name                      Company  \
# 5      6       Kirk  Strickland              Brewer-Thompson
# 6      7     Shelly      Ingram  Braun, Fernandez and Jacobs
# 7      8    Clayton     Maxwell                  Smith-Munoz
# 8      9      Tammy     Kaufman        Mayer, Bowen and Rowe
# 9     10    Deborah      Dunlap        Choi, Rush and Larsen
#
#                 City                       Country
# 5      North Madison      United States of America
# 6          Sydneyton                     Gibraltar
# 7      Triciaborough                   Puerto Rico
# 8     South Ginaside                         Spain
# 9  North Melindabury  United States Virgin Islands

# %%
sales=pd.read_csv("sale.csv")

# %%
sales
# Out:
#     number,first_name,last_name,gender,birth_date,employment_status,annual_salary,tax_file_no
# 0                 483,Lenord,Kihn,M,1994-07-01,,64598,
# 1             478,Palma,Beahan,F,1972-05-06,PE,124103,
# 2            348,Hebert,Muller,M,1990-09-04,PE,100324,
# 3         757,Virginia,Ullrich,M,1991-09-23,PE,144957,
# 4                937,Roby,Hudson,M,1997-01-15,,137659,
# ..                                                 ...
# 995              712,Dann,Crooks,,1983-12-25,CA,66592,
# 996              132,Maxim,Orn,M,1971-03-01,CA,127966,
# 997         126,Kimberli,Walter,M,1976-03-07,CA,60712,
# 998        277,Talmage,Bartell,F,1989-02-19,PE,103606,
# 999          960,Laurie,Nienow,M,1993-04-01,PE,127405,
#
# [1000 rows x 1 columns]

# %%
sales=pd.read_csv("sale.csv")

# %%
sales
# Out:
#      number first_name last_name gender  birth_date employment_status  \
# 0       483     Lenord      Kihn      M  1994-07-01               NaN
# 1       478      Palma    Beahan      F  1972-05-06                PE
# 2       348     Hebert    Muller      M  1990-09-04                PE
# 3       757   Virginia   Ullrich      M  1991-09-23                PE
# 4       937       Roby    Hudson      M  1997-01-15               NaN
# ..      ...        ...       ...    ...         ...               ...
# 995     712       Dann    Crooks    NaN  1983-12-25                CA
# 996     132      Maxim       Orn      M  1971-03-01                CA
# 997     126   Kimberli    Walter      M  1976-03-07                CA
# 998     277    Talmage   Bartell      F  1989-02-19                PE
# 999     960     Laurie    Nienow      M  1993-04-01                PE
#
#      annual_salary  tax_file_no
# 0          64598.0          NaN
# 1         124103.0          NaN
# ...

# %%
sales['employment_status'].unique()
# Out:
# array([nan, 'PE', 'CA', 'TE'], dtype=object)

# %%
sales[sales['employment_status']=='PE']
# Out:
#      number first_name last_name gender  birth_date employment_status  \
# 1       478      Palma    Beahan      F  1972-05-06                PE
# 2       348     Hebert    Muller      M  1990-09-04                PE
# 3       757   Virginia   Ullrich      M  1991-09-23                PE
# 5       264      Jaeda   Effertz    NaN  1994-03-21                PE
# 6       165    Jalissa  Bogisich      F  1974-01-07                PE
# ..      ...        ...       ...    ...         ...               ...
# 990     916     Jerrad       Orn    NaN  1976-12-15                PE
# 992     308    Elberta    Harvey      F  1988-12-29                PE
# 993     799  Valentino    Hudson      M  1988-09-16                PE
# 998     277    Talmage   Bartell      F  1989-02-19                PE
# 999     960     Laurie    Nienow      M  1993-04-01                PE
#
#      annual_salary  tax_file_no
# 1         124103.0          NaN
# 2         100324.0          NaN
# ...

# %%
sales[sales['employment_status']=='NaN']
# Out:
# Empty DataFrame
# Columns: [number, first_name, last_name, gender, birth_date, employment_status, annual_salary, tax_file_no]
# Index: []

# %%
sales
# Out:
#      number first_name last_name gender  birth_date employment_status  \
# 0       483     Lenord      Kihn      M  1994-07-01               NaN
# 1       478      Palma    Beahan      F  1972-05-06                PE
# 2       348     Hebert    Muller      M  1990-09-04                PE
# 3       757   Virginia   Ullrich      M  1991-09-23                PE
# 4       937       Roby    Hudson      M  1997-01-15               NaN
# ..      ...        ...       ...    ...         ...               ...
# 995     712       Dann    Crooks    NaN  1983-12-25                CA
# 996     132      Maxim       Orn      M  1971-03-01                CA
# 997     126   Kimberli    Walter      M  1976-03-07                CA
# 998     277    Talmage   Bartell      F  1989-02-19                PE
# 999     960     Laurie    Nienow      M  1993-04-01                PE
#
#      annual_salary  tax_file_no
# 0          64598.0          NaN
# 1         124103.0          NaN
# ...

# %%
 sales[(sales['annual_salary'] > 10000) & (sales['annual_salary'] < 15000)]
# Out:
# Empty DataFrame
# Columns: [number, first_name, last_name, gender, birth_date, employment_status, annual_salary, tax_file_no]
# Index: []

# %%
sales
# Out:
#      number first_name last_name gender  birth_date employment_status  \
# 0       483     Lenord      Kihn      M  1994-07-01               NaN
# 1       478      Palma    Beahan      F  1972-05-06                PE
# 2       348     Hebert    Muller      M  1990-09-04                PE
# 3       757   Virginia   Ullrich      M  1991-09-23                PE
# 4       937       Roby    Hudson      M  1997-01-15               NaN
# ..      ...        ...       ...    ...         ...               ...
# 995     712       Dann    Crooks    NaN  1983-12-25                CA
# 996     132      Maxim       Orn      M  1971-03-01                CA
# 997     126   Kimberli    Walter      M  1976-03-07                CA
# 998     277    Talmage   Bartell      F  1989-02-19                PE
# 999     960     Laurie    Nienow      M  1993-04-01                PE
#
#      annual_salary  tax_file_no
# 0          64598.0          NaN
# 1         124103.0          NaN
# ...

# %%
sales[sales['annual_salary']>10000]
# Out:
#      number first_name last_name gender  birth_date employment_status  \
# 0       483     Lenord      Kihn      M  1994-07-01               NaN
# 1       478      Palma    Beahan      F  1972-05-06                PE
# 2       348     Hebert    Muller      M  1990-09-04                PE
# 3       757   Virginia   Ullrich      M  1991-09-23                PE
# 4       937       Roby    Hudson      M  1997-01-15               NaN
# ..      ...        ...       ...    ...         ...               ...
# 995     712       Dann    Crooks    NaN  1983-12-25                CA
# 996     132      Maxim       Orn      M  1971-03-01                CA
# 997     126   Kimberli    Walter      M  1976-03-07                CA
# 998     277    Talmage   Bartell      F  1989-02-19                PE
# 999     960     Laurie    Nienow      M  1993-04-01                PE
#
#      annual_salary  tax_file_no
# 0          64598.0          NaN
# 1         124103.0          NaN
# ...

# %%
sales=pd.read_csv("sale.csv")

# %%
sales[(sales['annual_salary'] > 100000) & (sales['annual_salary'] < 150000)]
# Out:
#      number first_name last_name gender  birth_date employment_status  \
# 1       478      Palma    Beahan      F  06/05/1972                PE
# 2       348     Hebert    Muller      M  04/09/1990                PE
# 3       757   Virginia   Ullrich      M  23/09/1991                PE
# 4       937       Roby    Hudson      M  15/01/1997               NaN
# 5       264      Jaeda   Effertz    NaN  21/03/1994                PE
# ..      ...        ...       ...    ...         ...               ...
# 992     308    Elberta    Harvey      F  29/12/1988                PE
# 994     606      Patty     Swift      F  26/12/1987                CA
# 996     132      Maxim       Orn      M  01/03/1971                CA
# 998     277    Talmage   Bartell      F  19/02/1989                PE
# 999     960     Laurie    Nienow      M  01/04/1993                PE
#
#      annual_salary  tax_file_no
# 1         124103.0          NaN
# 2         100324.0          NaN
# ...

# %%
sales[sales['employment_status']=='PE']
# Out:
#      number first_name last_name gender  birth_date employment_status  \
# 1       478      Palma    Beahan      F  06/05/1972                PE
# 2       348     Hebert    Muller      M  04/09/1990                PE
# 3       757   Virginia   Ullrich      M  23/09/1991                PE
# 5       264      Jaeda   Effertz    NaN  21/03/1994                PE
# 6       165    Jalissa  Bogisich      F  07/01/1974                PE
# ..      ...        ...       ...    ...         ...               ...
# 990     916     Jerrad       Orn    NaN  15/12/1976                PE
# 992     308    Elberta    Harvey      F  29/12/1988                PE
# 993     799  Valentino    Hudson      M  16/09/1988                PE
# 998     277    Talmage   Bartell      F  19/02/1989                PE
# 999     960     Laurie    Nienow      M  01/04/1993                PE
#
#      annual_salary  tax_file_no
# 1         124103.0          NaN
# 2         100324.0          NaN
# ...

# %%
sales['employment_status'].unique()
# Out:
# array([nan, 'PE', 'CA', 'TE'], dtype=object)

# %%
sales[(sales['annual_salary'] > 100000) & (sales['annual_salary'] < 150000)]
# Out:
#      number first_name last_name gender  birth_date employment_status  \
# 1       478      Palma    Beahan      F  06/05/1972                PE
# 2       348     Hebert    Muller      M  04/09/1990                PE
# 3       757   Virginia   Ullrich      M  23/09/1991                PE
# 4       937       Roby    Hudson      M  15/01/1997               NaN
# 5       264      Jaeda   Effertz    NaN  21/03/1994                PE
# ..      ...        ...       ...    ...         ...               ...
# 992     308    Elberta    Harvey      F  29/12/1988                PE
# 994     606      Patty     Swift      F  26/12/1987                CA
# 996     132      Maxim       Orn      M  01/03/1971                CA
# 998     277    Talmage   Bartell      F  19/02/1989                PE
# 999     960     Laurie    Nienow      M  01/04/1993                PE
#
#      annual_salary  tax_file_no
# 1         124103.0          NaN
# 2         100324.0          NaN
# ...

# %%
sales['annual_salary'].sum()
# Out:
# 101915179.0

# %%
sales.head
# Out:
# <bound method NDFrame.head of      number first_name last_name gender  birth_date employment_status  \
# 0       483     Lenord      Kihn      M  01/07/1994               NaN
# 1       478      Palma    Beahan      F  06/05/1972                PE
# 2       348     Hebert    Muller      M  04/09/1990                PE
# 3       757   Virginia   Ullrich      M  23/09/1991                PE
# 4       937       Roby    Hudson      M  15/01/1997               NaN
# ..      ...        ...       ...    ...         ...               ...
# 995     712       Dann    Crooks    NaN  25/12/1983                CA
# 996     132      Maxim       Orn      M  01/03/1971                CA
# 997     126   Kimberli    Walter      M  07/03/1976                CA
# 998     277    Talmage   Bartell      F  19/02/1989                PE
# 999     960     Laurie    Nienow      M  01/04/1993                PE
#
#      annual_salary  tax_file_no
# 0          64598.0          NaN
# ...

# %%
sales['annual_salary'].sum()
# Out:
# 101915179.0

# %%
sales
# Out:
#      number first_name last_name gender  birth_date employment_status  \
# 0       483     Lenord      Kihn      M  01/07/1994               NaN
# 1       478      Palma    Beahan      F  06/05/1972                PE
# 2       348     Hebert    Muller      M  04/09/1990                PE
# 3       757   Virginia   Ullrich      M  23/09/1991                PE
# 4       937       Roby    Hudson      M  15/01/1997               NaN
# ..      ...        ...       ...    ...         ...               ...
# 995     712       Dann    Crooks    NaN  25/12/1983                CA
# 996     132      Maxim       Orn      M  01/03/1971                CA
# 997     126   Kimberli    Walter      M  07/03/1976                CA
# 998     277    Talmage   Bartell      F  19/02/1989                PE
# 999     960     Laurie    Nienow      M  01/04/1993                PE
#
#      annual_salary  tax_file_no
# 0          64598.0          NaN
# 1         124103.0          NaN
# ...

# %%
sales.head()
# Out:
#    number first_name last_name gender  birth_date employment_status  \
# 0     483     Lenord      Kihn      M  01/07/1994               NaN
# 1     478      Palma    Beahan      F  06/05/1972                PE
# 2     348     Hebert    Muller      M  04/09/1990                PE
# 3     757   Virginia   Ullrich      M  23/09/1991                PE
# 4     937       Roby    Hudson      M  15/01/1997               NaN
#
#    annual_salary  tax_file_no
# 0        64598.0          NaN
# 1       124103.0          NaN
# 2       100324.0          NaN
# 3       144957.0          NaN
# 4       137659.0          NaN

# %%
sales['number'].sum()
# Out:
# 499502

# %%
sales['annual_salary'].sum()
# Out:
# 101915179.0

# %%
sales['annual_salary'].max()
# Out:
# 149999.0

# %%
sales['number'].max()
# Out:
# 999

# %%
sales[sales['annual_salary']==sales['annual_salary'].max()]
# Out:
#      number first_name last_name gender  birth_date employment_status  \
# 665     257     Vergie  Tremblay      F  09/12/1987                CA
#
#      annual_salary  tax_file_no
# 665       149999.0          NaN

# %%
sales['annual_salary'].min()
# Out:
# 55003.0

# %%
sales[sales['annual_salary']==sales['annual_salary'].min()]
# Out:
#      number first_name last_name gender  birth_date employment_status  \
# 373     195    Mustafa     Emard      M  16/03/1972                PE
#
#      annual_salary  tax_file_no
# 373        55003.0          NaN

# %%
sales['annual_salary'].mean()
# Out:
# 102017.1961961962
