# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
data=pd.read_csv("housesale.csv")

# %%
data.head()
# Out:
#    price  resid_area  air_qual  dist1  dist2  dist3  dist4  teachers  \
# 0   24.0       32.31     0.589      2      2      2    2.0        24
# 1   21.6       37.07     0.532      4      2      3    3.0        24
# 2   34.7       37.07     0.425      3      2      1    1.0        24
# 3   33.4       37.07     0.485      3      2      3    3.0        24
# 4   36.9       37.07     0.564      3      3      3    3.0        24
#
#    poor_prop airport  n_hos_beds  n_hot_rooms waterbody  rainfall bus_ter  \
# 0        4.5      No       18.30       11.120     River        23      No
# 1        9.2      No       17.84       12.178      Lake        42     Yes
# 2        5.6      No       17.37       12.200       NaN        39      No
# 3        7.2      No        8.60       10.200      Lake        56      No
# 4        4.5      No        8.60       10.740      Lake        45     Yes
#
#     parks  Sold
# 0  0.0500     0
# 1  0.0469     1
# 2  0.0438     0
# 3  0.0407     0
# 4  0.0376     0

# %%
data.shape
# Out:
# (100, 17)

# %%
data.describe()
# Out:
#             price  resid_area    air_qual       dist1       dist2       dist3  \
# count  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# mean    23.733000   36.886000    0.457596    3.040000    2.420000    2.510000
# std      6.841363    1.584873    0.174682    0.723627    0.496045    1.029808
# min     12.500000   32.310000    0.045400    2.000000    2.000000    1.000000
# 25%     18.600000   37.070000    0.425000    3.000000    2.000000    2.000000
# 50%     22.400000   37.070000    0.532000    3.000000    2.000000    3.000000
# 75%     26.900000   38.140000    0.564000    4.000000    3.000000    3.000000
# max     36.900000   38.140000    0.589000    5.000000    3.000000    6.000000
#
#             dist4   teachers  poor_prop  n_hos_beds  n_hot_rooms    rainfall  \
# count  100.000000  100.00000  100.00000  100.000000   100.000000  100.000000
# mean     2.737279   20.98000    5.43800    5.498300    11.571310   43.120000
# ...

# %%
movie=pd.read_csv("HollywoodMovies.csv")

# %%
movie
# Out:
#                                          Movie              LeadStudio  \
# 0                                 Spider-Man 3                    Sony
# 1                              Shrek the Third               Paramount
# 2                                 Transformers               Paramount
# 3     Pirates of the Caribbean: At World's End                  Disney
# 4    Harry Potter and the Order of the Phoenix             Warner Bros
# ..                                         ...                     ...
# 965                                The Canyons                     IFC
# 966                                   The Call                 TriStar
# 967                        The English Teacher  Cinedigm Entertainment
# 968                       John Dies at the End                Magnolia
# 969                                   Lovelace              Radius-TWC
#
#      RottenTomatoes  AudienceScore          Story      Genre  \
# ...

# %%
movie.shape
# Out:
# (970, 16)

# %%
movie.describe()
# Out:
#        RottenTomatoes  AudienceScore  TheatersOpenWeek  OpeningWeekend  \
# count      913.000000     907.000000        949.000000      969.000000
# mean        51.707558      61.271224       2495.246575       20.620826
# std         26.821268      16.602457       1164.223356       25.338689
# min          0.000000      19.000000          1.000000        0.010000
# 25%         28.000000      49.000000       2054.000000        5.300000
# 50%         52.000000      61.000000       2798.000000       13.150000
# 75%         75.000000      74.000000       3285.000000       26.200000
# max         99.000000      96.000000       4468.000000      207.440000
#
#        BOAvgOpenWeekend  DomesticGross  ForeignGross   WorldGross      Budget  \
# count        945.000000     970.000000    876.000000   914.000000  897.000000
# mean        8562.593651      68.162544    101.237419   169.009945   56.117168
# std        10645.135565      80.409969    155.987696   227.744380   53.755914
# ...

# %%
sns.boxplot(y='n_hos_beds',data=data)
# Out:
# <Axes: ylabel='n_hos_beds'>

# %%
sns.boxplot(y='n_hot_rooms',data=data)
# Out:
# <Axes: ylabel='n_hot_rooms'>

# %%
sns.jointplot(x='rainfall',y='Sold',data=data)
# Out:
# C:\Users\divya.sunil\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\divya.sunil\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.countplot(x='airport',data=data)
# Out:
# <Axes: xlabel='airport', ylabel='count'>

# %%
sns.countplot(x='waterbody',data=data)
# Out:
# <Axes: xlabel='waterbody', ylabel='count'>

# %%
sns.countplot(x='bus_ter',data=data)
# Out:
# <Axes: xlabel='bus_ter', ylabel='count'>

# %%
observation
missing values in n_hos_beds
bus_ter no details
n_hot_rooms and rainfall haveoutliers

# %%
np.percentile(data.n_hot_rooms,[99][0])
# Out:
# 29.347000000000026

# %%
uv=np.percentile(data.n_hot_rooms,[99][0])

# %%
data.n_hot_rooms[(data.n_hot_rooms>2 *uv)]=2*uv
# Out:
# C:\Users\divya.sunil\AppData\Local\Temp\ipykernel_1768\2053595202.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.n_hot_rooms[(data.n_hot_rooms>2 *uv)]=2*uv

# %%
data[(data.n_hot_rooms>uv)]
# Out:
#     price  resid_area  air_qual  dist1  dist2  dist3  dist4  teachers  \
# 40   24.4       37.07    0.0454      2      2      1    2.0        19
#
#     poor_prop airport  n_hos_beds  n_hot_rooms waterbody  rainfall bus_ter  \
# 40        9.1      No         9.1         34.0     River        44      No
#
#     parks  Sold
# 40  0.088     0

# %%
np.percentile(data.rainfall,[1])[0]
# Out:
# 23.0

# %%
lv=np.percentile(data.rainfall,[1])[0]

# %%
data[data.rainfall<lv]
# Out:
# Empty DataFrame
# Columns: [price, resid_area, air_qual, dist1, dist2, dist3, dist4, teachers, poor_prop, airport, n_hos_beds, n_hot_rooms, waterbody, rainfall, bus_ter, parks, Sold]
# Index: []

# %%
data.rainfall[(data.rainfall>0.3 *lv)]=0.3*lv
# Out:
# C:\Users\divya.sunil\AppData\Local\Temp\ipykernel_1768\60795285.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.rainfall[(data.rainfall>0.3 *lv)]=0.3*lv
# C:\Users\divya.sunil\AppData\Local\Temp\ipykernel_1768\60795285.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '6.8999999999999995' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.rainfall[(data.rainfall>0.3 *lv)]=0.3*lv

# %%
data.describe()
# Out:
#             price  resid_area    air_qual       dist1       dist2       dist3  \
# count  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# mean    23.733000   36.886000    0.457596    3.040000    2.420000    2.510000
# std      6.841363    1.584873    0.174682    0.723627    0.496045    1.029808
# min     12.500000   32.310000    0.045400    2.000000    2.000000    1.000000
# 25%     18.600000   37.070000    0.425000    3.000000    2.000000    2.000000
# 50%     22.400000   37.070000    0.532000    3.000000    2.000000    3.000000
# 75%     26.900000   38.140000    0.564000    4.000000    3.000000    3.000000
# max     36.900000   38.140000    0.589000    5.000000    3.000000    6.000000
#
#             dist4   teachers  poor_prop  n_hos_beds  n_hot_rooms  \
# count  100.000000  100.00000  100.00000  100.000000   100.000000
# mean     2.737279   20.98000    5.43800    5.498300     6.528720
# std      0.938362    1.86937    1.83175    3.151635     0.994222
# ...
