# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
data=pd.read_csv("housesale.csv")

# %%
data.describe()
# Out:
#             price  resid_area    air_qual       dist1       dist2       dist3  \
# count  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# mean    23.733000   36.886000    0.457596    3.040000    2.420000    2.510000
# std      6.841363    1.584873    0.174682    0.723627    0.496045    1.029808
# min     12.500000   32.310000    0.045400    2.000000    2.000000    1.000000
# 25%     18.600000   37.070000    0.425000    3.000000    2.000000    2.000000
# 50%     22.400000   37.070000    0.532000    3.000000    2.000000    3.000000
# 75%     26.900000   38.140000    0.564000    4.000000    3.000000    3.000000
# max     36.900000   38.140000    0.589000    5.000000    3.000000    6.000000
#
#             dist4   teachers  poor_prop  n_hos_beds  n_hot_rooms    rainfall  \
# count  100.000000  100.00000  100.00000   92.000000   100.000000  100.000000
# mean     2.737279   20.98000    5.43800    5.546522    11.571310   43.120000
# ...

# %%
data=pd.get_dummies(data)

# %%
data.head()
# Out:
#    price  resid_area  air_qual  dist1  dist2  dist3  dist4  teachers  \
# 0   24.0       32.31     0.589      2      2      2    2.0        24
# 1   21.6       37.07     0.532      4      2      3    3.0        24
# 2   34.7       37.07     0.425      3      2      1    1.0        24
# 3   33.4       37.07     0.485      3      2      3    3.0        24
# 4   36.9       37.07     0.564      3      3      3    3.0        24
#
#    poor_prop  n_hos_beds  ...  rainfall   parks  Sold  airport_No  \
# 0        4.5       18.30  ...        23  0.0500     0        True
# 1        9.2       17.84  ...        42  0.0469     1        True
# 2        5.6       17.37  ...        39  0.0438     0        True
# 3        7.2        8.60  ...        56  0.0407     0        True
# 4        4.5        8.60  ...        45  0.0376     0        True
#
#    airport_Yes  waterbody_Lake  waterbody_Lake & River  waterbody_River  \
# 0        False           False                   False             True
# ...

# %%
del data['airport_No']

# %%
del data['bus_ter_No']

# %%
data.head()
# Out:
#    price  resid_area  air_qual  dist1  dist2  dist3  dist4  teachers  \
# 0   24.0       32.31     0.589      2      2      2    2.0        24
# 1   21.6       37.07     0.532      4      2      3    3.0        24
# 2   34.7       37.07     0.425      3      2      1    1.0        24
# 3   33.4       37.07     0.485      3      2      3    3.0        24
# 4   36.9       37.07     0.564      3      3      3    3.0        24
#
#    poor_prop  n_hos_beds  n_hot_rooms  rainfall   parks  Sold  airport_Yes  \
# 0        4.5       18.30       11.120        23  0.0500     0        False
# 1        9.2       17.84       12.178        42  0.0469     1        False
# 2        5.6       17.37       12.200        39  0.0438     0        False
# 3        7.2        8.60       10.200        56  0.0407     0        False
# 4        4.5        8.60       10.740        45  0.0376     0        False
#
#    waterbody_Lake  waterbody_Lake & River  waterbody_River  bus_ter_Yes
# ...

# %%
del data['dist1']
del data['dist2']
del data['dist3']
del data['dist4']

# %%
data.head()
# Out:
#    price  resid_area  air_qual  teachers  poor_prop  n_hos_beds  n_hot_rooms  \
# 0   24.0       32.31     0.589        24        4.5       18.30       11.120
# 1   21.6       37.07     0.532        24        9.2       17.84       12.178
# 2   34.7       37.07     0.425        24        5.6       17.37       12.200
# 3   33.4       37.07     0.485        24        7.2        8.60       10.200
# 4   36.9       37.07     0.564        24        4.5        8.60       10.740
#
#    rainfall   parks  Sold  airport_Yes  waterbody_Lake  \
# 0        23  0.0500     0        False           False
# 1        42  0.0469     1        False            True
# 2        39  0.0438     0        False           False
# 3        56  0.0407     0        False            True
# 4        45  0.0376     0        False            True
#
#    waterbody_Lake & River  waterbody_River  bus_ter_Yes
# 0                   False             True        False
# 1                   False            False         True
# ...
