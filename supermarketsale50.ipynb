# %%
import pandas as pd

# %%
sale=pd.read_csv("supermarketsale.csv")

# %%
sale
# Out:
#     Row ID        Order ID Order Date Ship Date       Ship Mode Customer ID  \
# 0        1  CA-2016-152156     08-Nov    11-Nov    Second Class    CG-12520
# 1        2  CA-2016-152156     08-Nov    11-Nov    Second Class    CG-12520
# 2        3  CA-2016-138688     12-Jun    16-Jun    Second Class    DV-13045
# 3        4  US-2015-108966     11-Oct    18-Oct  Standard Class    SO-20335
# 4        5  US-2015-108966     11-Oct    18-Oct  Standard Class    SO-20335
# ..     ...             ...        ...       ...             ...         ...
# 95      96  US-2017-109484     06-Nov    12-Nov  Standard Class    RB-19705
# 96      97  CA-2017-161018     09-Nov    11-Nov    Second Class    PN-18775
# 97      98  CA-2017-157833     17-Jun    20-Jun     First Class    KD-16345
# 98      99  CA-2016-149223     06-Sep    11-Sep  Standard Class    ER-13855
# 99     100  CA-2016-158568     29-Aug    02-Sep  Standard Class    RB-19465
#
# ...

# %%
sale.groupby('City').sum()
# Out:
#                  Row ID                                           Order ID  \
# City
# Chicago             252         US-2015-164175US-2017-119662CA-2016-158568
# Columbia             86                                     CA-2017-140088
# Concord              13                                     CA-2017-114412
# Decatur             161                       CA-2016-127208CA-2016-127208
# Dover                97                       CA-2016-169194CA-2016-169194
# Durham               84                                     CA-2015-149734
# Eagan                91                       CA-2016-118255CA-2016-118255
# Fort Lauderdale       9                       US-2015-108966US-2015-108966
# Fort Worth           31                       US-2015-118983US-2015-118983
# Fremont              45                       CA-2016-137330CA-2016-137330
# Gilbert             137                       CA-2014-106376CA-2014-106376
# ...

# %%
sale.groupby('City').sum()['Sales']
# Out:
# City
# Chicago             508.1150
# Columbia            301.9600
# Concord              15.5520
# Decatur             224.9000
# Dover                66.8000
# Durham              200.9840
# Eagan                63.4400
# Fort Lauderdale     979.9455
# Fort Worth           71.3540
# Fremont              79.8000
# Gilbert            1280.9920
# Henderson           993.9000
# Houston            1474.2892
# Jackson              19.0500
# Los Angeles        4275.4800
# Madison             665.8800
# Melbourne            95.6160
# Memphis            1001.7600
# Minneapolis          99.2600
# Naperville          147.1680
# New Albany          209.5500
# New York City      1146.3560
# Orem               1044.6300
# Philadelphia       3400.8060
# Portland              5.6820
# Richardson         1288.4640
# Rochester            26.1500
# Saint Paul           77.8800
# San Francisco       332.3620
# Seattle             407.9760
# Springfield          75.8800
# Troy                655.0900
# ...

# %%
sale.groupby('Order Date').sum()['Sales']
# Out:
# Order Date
# 03-Sep     200.9840
# 04-Jun      75.8800
# 05-Apr     158.3680
# 05-Dec    1688.9680
# 06-Nov       5.6820
# 06-Sep      77.8800
# 08-Dec    1288.4640
# 08-Nov     993.9000
# 09-Dec     117.9960
# 09-Jun    3714.3040
# 09-Nov      96.5300
# 10-Sep     147.1680
# 11-Dec    1045.2100
# 11-Mar      63.4400
# 11-Nov     665.8800
# 11-Oct     979.9455
# 12-Jun     239.5200
# 12-Oct      36.2900
# 13-May      55.5000
# 13-Nov     230.3760
# 14-Sep      19.0500
# 15-Apr      15.5520
# 16-Jan     102.2180
# 16-Jul      71.3720
# 17-Jul      77.8800
# 17-Jun     706.4020
# 17-Sep    3429.5980
# 18-Apr     209.5500
# 18-Sep       4.6160
# 19-Oct      29.4720
# 19-Sep      95.6160
# 20-Jun      66.8000
# 20-Oct     211.9600
# 22-Nov      71.3540
# 24-Nov     266.2940
# 25-Sep    1044.6300
# 26-Apr    1001.7600
# 26-Nov      19.3000
# 26-Oct      26.1500
# 27-Aug     244.7600
# 27-Dec    1228.9532
# 28-May     301.9600
# 29-Aug      64.6240
# 30-Apr     213.1150
# ...

# %%
sale.groupby('Product Name').sum()['Sales']
# Out:
# Product Name
# #10-4 1/8" x 9 1/2" Premium Diagonal Seam Envelopes     113.328
# 1.7 Cubic Foot Compact "Cube" Office Refrigerators      208.160
# 6" Cubicle Wall Clock, Black                              9.708
# 9-3/4 Diameter Round Wall Clock                          96.530
# AT&T CL83451 4-Handset Telephone                       1029.950
#                                                          ...
# Xerox 1967                                               15.552
# Xerox 1995                                                6.480
# Xerox 1999                                               12.960
# Xerox 232                                                32.400
# netTALK DUO VoIP Telephone Service                      167.968
# Name: Sales, Length: 97, dtype: float64

# %%
sales=pd.read_csv("salelist.csv")

# %%
sales
# Out:
#     Row ID      Invoice ID Order Date Gender       Customer Name      Segment  \
# 0        1  CA-2016-152156     08-Nov      M         Claire Gute     Consumer
# 1        2  CA-2016-152156     08-Nov      M         Claire Gute     Consumer
# 2        3  CA-2016-138688     12-Jun      M     Darrin Van Huff    Corporate
# 3        4  US-2015-108966     11-Oct      M      Sean O'Donnell     Consumer
# 4        5  US-2015-108966     11-Oct      F      Sean O'Donnell     Consumer
# 5        6  CA-2014-115812     09-Jun      M     Brosina Hoffman     Consumer
# 6        7  CA-2014-115812     09-Jun      F     Brosina Hoffman     Consumer
# 7        8  CA-2014-115812     09-Jun      M     Brosina Hoffman     Consumer
# 8        9  CA-2014-115812     09-Jun      F     Brosina Hoffman     Consumer
# 9       10  CA-2014-115812     09-Jun      F     Brosina Hoffman     Consumer
# 10      11  CA-2014-115812     09-Jun      F     Brosina Hoffman     Consumer
# ...

# %%
sales.groupby('Gender').sum()['Total']
# Out:
# Gender
# F    6037
# M    6422
# Name: Total, dtype: int64

# %%
sales.groupby(['Gender','Payment']).sum()['Total']
# Out:
# Gender  Payment
# F       Card        1239
#         Cash        4198
#         Gpay         446
#         PhonePay     154
# M       Card         635
#         Cash        4598
#         Gpay         188
#         PhonePay    1001
# Name: Total, dtype: int64

# %%
sales.groupby(['City','Payment']).sum()['Total']
# Out:
# City             Payment
# Concord          Card          44
# Dover            Cash         150
#                  PhonePay     200
# Eagan            Cash         145
#                  PhonePay     154
# Fort Lauderdale  Cash         484
# Fort Worth       Cash         142
# Fremont          Cash         221
# Henderson        Cash          75
# Houston          Cash        1651
#                  PhonePay     546
# Los Angeles      Card         101
#                  Cash        1904
#                  Gpay          55
#                  PhonePay     255
# Madison          Card         600
# Melbourne        Cash         214
# Naperville       Cash         254
# New Albany       Card         100
# Orem             Gpay         346
# Philadelphia     Card        1029
#                  Cash        1518
#                  Gpay          45
# Richardson       Cash         955
#                  Gpay          88
# San Francisco    Cash         788
#                  Gpay         100
# ...

# %%
# which location has highest and lowest sales
# represent a sale bar chart, with market share based on location using pie chart

# %%
sales
# Out:
#     Row ID      Invoice ID Order Date Gender       Customer Name      Segment  \
# 0        1  CA-2016-152156     08-Nov      M         Claire Gute     Consumer
# 1        2  CA-2016-152156     08-Nov      M         Claire Gute     Consumer
# 2        3  CA-2016-138688     12-Jun      M     Darrin Van Huff    Corporate
# 3        4  US-2015-108966     11-Oct      M      Sean O'Donnell     Consumer
# 4        5  US-2015-108966     11-Oct      F      Sean O'Donnell     Consumer
# 5        6  CA-2014-115812     09-Jun      M     Brosina Hoffman     Consumer
# 6        7  CA-2014-115812     09-Jun      F     Brosina Hoffman     Consumer
# 7        8  CA-2014-115812     09-Jun      M     Brosina Hoffman     Consumer
# 8        9  CA-2014-115812     09-Jun      F     Brosina Hoffman     Consumer
# 9       10  CA-2014-115812     09-Jun      F     Brosina Hoffman     Consumer
# 10      11  CA-2014-115812     09-Jun      F     Brosina Hoffman     Consumer
# ...

# %%
LocationList= sales.groupby('City')

# %%
location=[x for x,y in LocationList]

# %%
location
# Out:
# ['Concord',
#  'Dover',
#  'Eagan',
#  'Fort Lauderdale',
#  'Fort Worth',
#  'Fremont',
#  'Henderson',
#  'Houston',
#  'Los Angeles',
#  'Madison',
#  'Melbourne',
#  'Naperville',
#  'New Albany',
#  'Orem',
#  'Philadelphia',
#  'Richardson',
#  'San Francisco',
#  'Seattle',
#  'West Jordan',
#  'Westland']

# %%
sales.groupby('City').sum()['Total']
# Out:
# City
# Concord              44
# Dover               350
# Eagan               299
# Fort Lauderdale     484
# Fort Worth          142
# Fremont             221
# Henderson            75
# Houston            2197
# Los Angeles        2315
# Madison             600
# Melbourne           214
# Naperville          254
# New Albany          100
# Orem                346
# Philadelphia       2592
# Richardson         1043
# San Francisco       888
# Seattle              77
# West Jordan          54
# Westland            164
# Name: Total, dtype: int64

# %%
location_Total=sales.groupby('City').sum()['Total'].reset_index()

# %%
location_Total.sort_values(by='Total', ascending=False)
# Out:
#                City  Total
# 14     Philadelphia   2592
# 8       Los Angeles   2315
# 7           Houston   2197
# 15       Richardson   1043
# 16    San Francisco    888
# 9           Madison    600
# 3   Fort Lauderdale    484
# 1             Dover    350
# 13             Orem    346
# 2             Eagan    299
# 11       Naperville    254
# 5           Fremont    221
# 10        Melbourne    214
# 19         Westland    164
# 4        Fort Worth    142
# 12       New Albany    100
# 17          Seattle     77
# 6         Henderson     75
# 18      West Jordan     54
# 0           Concord     44

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(location,sales.groupby('City').sum()['Total'])
# Out:
# <BarContainer object of 20 artists>

# %%
plt.pie(sales.groupby('City').sum()['Total'],labels=location)
# Out:
# ([<matplotlib.patches.Wedge at 0x192406aa450>,
# ...
#  [Text(1.0999322987076592, 0.012204026371862896, 'Concord'),
#   Text(1.093298025286563, 0.12124119722479738, 'Dover'),
#   Text(1.0589385270687823, 0.2977401482658963, 'Eagan'),
#   Text(0.9799623249479683, 0.49967373523387526, 'Fort Lauderdale'),
#   Text(0.8892334528423063, 0.6475058813216681, 'Fort Worth'),
#   Text(0.8263261650944588, 0.7260751124231469, 'Fremont'),
#   Text(0.7698832937402673, 0.7856715051595276, 'Henderson'),
#   Text(0.22107340611448656, 1.077555821806434, 'Houston'),
#   Text(-0.8852986631142915, 0.6528753917004748, 'Los Angeles'),
#   Text(-1.094548314610418, -0.10938001180971664, 'Madison'),
#   Text(-1.0492796292335649, -0.3301700466054919, 'Melbourne'),
#   Text(-1.00310955779947, -0.4514102513804397, 'Naperville'),
#   Text(-0.9588753058059615, -0.5390344589314529, 'New Albany'),
#   Text(-0.8923254311544975, -0.64323815567404, 'Orem'),
#   Text(-0.22433296495523922, -1.0768819437776787, 'Philadelphia'),
# ...

# %%
plt.pie(sales.groupby('City').sum()['Total'],labels=location,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x192406f49d0>,
# ...
#  [Text(1.0999322987076592, 0.012204026371862896, 'Concord'),
#   Text(1.093298025286563, 0.12124119722479738, 'Dover'),
#   Text(1.0589385270687823, 0.2977401482658963, 'Eagan'),
#   Text(0.9799623249479683, 0.49967373523387526, 'Fort Lauderdale'),
#   Text(0.8892334528423063, 0.6475058813216681, 'Fort Worth'),
#   Text(0.8263261650944588, 0.7260751124231469, 'Fremont'),
#   Text(0.7698832937402673, 0.7856715051595276, 'Henderson'),
#   Text(0.22107340611448656, 1.077555821806434, 'Houston'),
#   Text(-0.8852986631142915, 0.6528753917004748, 'Los Angeles'),
#   Text(-1.094548314610418, -0.10938001180971664, 'Madison'),
#   Text(-1.0492796292335649, -0.3301700466054919, 'Melbourne'),
#   Text(-1.00310955779947, -0.4514102513804397, 'Naperville'),
#   Text(-0.9588753058059615, -0.5390344589314529, 'New Albany'),
#   Text(-0.8923254311544975, -0.64323815567404, 'Orem'),
#   Text(-0.22433296495523922, -1.0768819437776787, 'Philadelphia'),
# ...

# %%
#Location with more F/M customers

# %%
sales.groupby(['Gender','City']).sum()['Total']
# Out:
# Gender  City
# F       Concord              44
#         Eagan               154
#         Fort Lauderdale     400
#         Fremont             221
#         Houston             736
#         Los Angeles        1069
#         Madison             600
#         Melbourne           214
#         Orem                346
#         Philadelphia       1201
#         San Francisco       888
#         Westland            164
# M       Dover               350
#         Eagan               145
#         Fort Lauderdale      84
#         Fort Worth          142
#         Henderson            75
#         Houston            1461
#         Los Angeles        1246
#         Naperville          254
#         New Albany          100
#         Philadelphia       1391
#         Richardson         1043
#         Seattle              77
#         West Jordan          54
# Name: Total, dtype: int64

# %%
LocationSales=sales.groupby(['City','Gender']).count()['Invoice ID']

# %%
LocationSales
# Out:
# City             Gender
# Concord          F         1
# Dover            M         2
# Eagan            F         1
#                  M         1
# Fort Lauderdale  F         1
#                  M         1
# Fort Worth       M         2
# Fremont          F         2
# Henderson        M         2
# Houston          F         2
#                  M         3
# Los Angeles      F         6
#                  M         5
# Madison          F         1
# Melbourne        F         1
# Naperville       M         1
# New Albany       M         1
# Orem             F         1
# Philadelphia     F         3
#                  M         5
# Richardson       M         2
# San Francisco    F         3
# Seattle          M         1
# West Jordan      M         1
# Westland         F         1
# Name: Invoice ID, dtype: int64

# %%
LocationSales.unstack(level=0)
# Out:
# City    Concord  Dover  Eagan  Fort Lauderdale  Fort Worth  Fremont  \
# Gender
# F           1.0    NaN    1.0              1.0         NaN      2.0
# M           NaN    2.0    1.0              1.0         2.0      NaN
#
# City    Henderson  Houston  Los Angeles  Madison  Melbourne  Naperville  \
# Gender
# F             NaN      2.0          6.0      1.0        1.0         NaN
# M             2.0      3.0          5.0      NaN        NaN         1.0
#
# City    New Albany  Orem  Philadelphia  Richardson  San Francisco  Seattle  \
# Gender
# F              NaN   1.0           3.0         NaN            3.0      NaN
# M              1.0   NaN           5.0         2.0            NaN      1.0
#
# City    West Jordan  Westland
# Gender
# F               NaN       1.0
# M               1.0       NaN

# %%
LocationSales.plot(kind='bar')
# Out:
# <Axes: xlabel='City,Gender'>

# %%
LocationSale=sales.groupby(['Gender','State']).count()['Invoice ID']

# %%
LocationSale.unstack(level=0)
# Out:
# Gender            F    M
# State
# California      9.0  5.0
# Delaware        NaN  2.0
# Florida         2.0  1.0
# Illinois        NaN  1.0
# Indiana         NaN  1.0
# Kentucky        NaN  2.0
# Michigan        1.0  NaN
# Minnesota       1.0  1.0
# Nebraska        2.0  NaN
# North Carolina  1.0  NaN
# Pennsylvania    3.0  5.0
# Texas           2.0  7.0
# Utah            1.0  1.0
# Washington      NaN  1.0
# Wisconsin       1.0  NaN

# %%
LocationSale.plot(kind='bar')
# Out:
# <Axes: xlabel='Gender,State'>

# %%
sale25=pd.read_csv("saleList25.csv")

# %%
sale25
# Out:
#     Row ID      Invoice ID  Order Date Gender       Customer Name  \
# 0        1  CA-2016-152156  18/05/2024      M         Claire Gute
# 1        2  CA-2016-152156  18/05/2024      F         Claire Gute
# 2        3  CA-2016-138688  18/05/2024      M     Darrin Van Huff
# 3        4  US-2015-108966  18/05/2024      M      Sean O'Donnell
# 4        5  US-2015-108966  18/05/2024      F      Sean O'Donnell
# 5        6  CA-2014-115812  18/05/2024      M     Brosina Hoffman
# 6        7  CA-2014-115812  18/05/2024      F     Brosina Hoffman
# 7        8  CA-2014-115812  18/05/2024      M     Brosina Hoffman
# 8        9  CA-2014-115812  30/05/2024      F     Brosina Hoffman
# 9       10  CA-2014-115812  30/05/2024      F     Brosina Hoffman
# 10      11  CA-2014-115812  30/05/2024      F     Brosina Hoffman
# 11      12  CA-2014-115812  30/05/2024      M     Brosina Hoffman
# 12      13  CA-2017-114412  30/05/2024      M        Andrew Allen
# ...

# %%
sale25Statewise=sale25.groupby(['Gender','State']).count()['Invoice ID']

# %%
sale25New=sale25Statewise.unstack(level=0)

# %%
sale25New.plot(kind='bar')
# Out:
# <Axes: xlabel='State'>

# %%
sale25Statewise.plot(kind='bar',x='State')
# Out:
# <Axes: xlabel='Gender,State'>

# %%
# Which month have more sale

# %%
sale25
# Out:
#     Row ID      Invoice ID  Order Date Gender       Customer Name  \
# 0        1  CA-2016-152156  18/05/2024      M         Claire Gute
# 1        2  CA-2016-152156  18/05/2024      F         Claire Gute
# 2        3  CA-2016-138688  18/05/2024      M     Darrin Van Huff
# 3        4  US-2015-108966  18/05/2024      M      Sean O'Donnell
# 4        5  US-2015-108966  18/05/2024      F      Sean O'Donnell
# 5        6  CA-2014-115812  18/05/2024      M     Brosina Hoffman
# 6        7  CA-2014-115812  18/05/2024      F     Brosina Hoffman
# 7        8  CA-2014-115812  18/05/2024      M     Brosina Hoffman
# 8        9  CA-2014-115812  30/05/2024      F     Brosina Hoffman
# 9       10  CA-2014-115812  30/05/2024      F     Brosina Hoffman
# 10      11  CA-2014-115812  30/05/2024      F     Brosina Hoffman
# 11      12  CA-2014-115812  30/05/2024      M     Brosina Hoffman
# 12      13  CA-2017-114412  30/05/2024      M        Andrew Allen
# ...

# %%
sale25['Order Date']
# Out:
# 0     18/05/2024
# 1     18/05/2024
# 2     18/05/2024
# 3     18/05/2024
# 4     18/05/2024
# 5     18/05/2024
# 6     18/05/2024
# 7     18/05/2024
# 8     30/05/2024
# 9     30/05/2024
# 10    30/05/2024
# 11    30/05/2024
# 12    30/05/2024
# 13    11/06/2024
# 14    11/06/2024
# 15    11/06/2024
# 16    11/06/2024
# 17    11/06/2024
# 18    11/06/2024
# 19    11/06/2024
# 20    23/05/2024
# 21    23/05/2024
# 22    23/05/2024
# 23    23/05/2024
# 24    11/06/2024
# Name: Order Date, dtype: object

# %%
print(sale25[sale25['Order Date'].isnull()])
# Out:
# Empty DataFrame
# Columns: [Row ID, Invoice ID, Order Date, Gender, Customer Name, Segment, City, State, Member, Region, Category, Sub-Category, Price, Quantity, Total, Rating, Payment]
# Index: []

# %%
print(sale25['Order Date'].dtype)
# Out:
# object

# %%
sale25['Order Date'] = sale25['Order Date'].astype(str)

# %%
pd.to_datetime(sale25['Order Date'])
# Out:
# C:\Users\divya.sunil\AppData\Local\Temp\ipykernel_7688\3554579396.py:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   pd.to_datetime(sale25['Order Date'])
# 0    2024-05-18
# 1    2024-05-18
# 2    2024-05-18
# 3    2024-05-18
# 4    2024-05-18
# 5    2024-05-18
# 6    2024-05-18
# 7    2024-05-18
# 8    2024-05-30
# 9    2024-05-30
# 10   2024-05-30
# 11   2024-05-30
# 12   2024-05-30
# 13   2024-06-11
# 14   2024-06-11
# 15   2024-06-11
# 16   2024-06-11
# 17   2024-06-11
# 18   2024-06-11
# 19   2024-06-11
# 20   2024-05-23
# 21   2024-05-23
# 22   2024-05-23
# 23   2024-05-23
# 24   2024-06-11
# Name: Order Date, dtype: datetime64[ns]

# %%
pd.to_datetime(sale25['Order Date']).dt.month
# Out:
# C:\Users\divya.sunil\AppData\Local\Temp\ipykernel_7688\2924988962.py:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   pd.to_datetime(sale25['Order Date']).dt.month
# 0     5
# 1     5
# 2     5
# 3     5
# 4     5
# 5     5
# 6     5
# 7     5
# 8     5
# 9     5
# 10    5
# 11    5
# 12    5
# 13    6
# 14    6
# 15    6
# 16    6
# 17    6
# 18    6
# 19    6
# 20    5
# 21    5
# 22    5
# 23    5
# 24    6
# Name: Order Date, dtype: int32

# %%
pd.to_datetime(sale25['Order Date']).dt.day
# Out:
# C:\Users\divya.sunil\AppData\Local\Temp\ipykernel_7688\1366039478.py:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   pd.to_datetime(sale25['Order Date']).dt.day
# 0     18
# 1     18
# 2     18
# 3     18
# 4     18
# 5     18
# 6     18
# 7     18
# 8     30
# 9     30
# 10    30
# 11    30
# 12    30
# 13    11
# 14    11
# 15    11
# 16    11
# 17    11
# 18    11
# 19    11
# 20    23
# 21    23
# 22    23
# 23    23
# 24    11
# Name: Order Date, dtype: int32

# %%
pd.to_datetime(sale25['Order Date']).dt.year
# Out:
# C:\Users\divya.sunil\AppData\Local\Temp\ipykernel_7688\304540299.py:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   pd.to_datetime(sale25['Order Date']).dt.year
# 0     2024
# 1     2024
# 2     2024
# 3     2024
# 4     2024
# 5     2024
# 6     2024
# 7     2024
# 8     2024
# 9     2024
# 10    2024
# 11    2024
# 12    2024
# 13    2024
# 14    2024
# 15    2024
# 16    2024
# 17    2024
# 18    2024
# 19    2024
# 20    2024
# 21    2024
# 22    2024
# 23    2024
# 24    2024
# Name: Order Date, dtype: int32

# %%
sale25['day']=pd.to_datetime(sale25['Order Date']).dt.day
# Out:
# C:\Users\divya.sunil\AppData\Local\Temp\ipykernel_7688\1415346971.py:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   sale25['day']=pd.to_datetime(sale25['Order Date']).dt.day

# %%
sale25
# Out:
#     Row ID      Invoice ID  Order Date Gender       Customer Name  \
# 0        1  CA-2016-152156  18/05/2024      M         Claire Gute
# 1        2  CA-2016-152156  18/05/2024      F         Claire Gute
# 2        3  CA-2016-138688  18/05/2024      M     Darrin Van Huff
# 3        4  US-2015-108966  18/05/2024      M      Sean O'Donnell
# 4        5  US-2015-108966  18/05/2024      F      Sean O'Donnell
# 5        6  CA-2014-115812  18/05/2024      M     Brosina Hoffman
# 6        7  CA-2014-115812  18/05/2024      F     Brosina Hoffman
# 7        8  CA-2014-115812  18/05/2024      M     Brosina Hoffman
# 8        9  CA-2014-115812  30/05/2024      F     Brosina Hoffman
# 9       10  CA-2014-115812  30/05/2024      F     Brosina Hoffman
# 10      11  CA-2014-115812  30/05/2024      F     Brosina Hoffman
# 11      12  CA-2014-115812  30/05/2024      M     Brosina Hoffman
# 12      13  CA-2017-114412  30/05/2024      M        Andrew Allen
# ...

# %%
daybasedSale=sale25.groupby('day')['Total'].sum()

# %%
daybasedSale
# Out:
# day
# 11    2007
# 18    1436
# 23     676
# 30     334
# Name: Total, dtype: int64

# %%
daybasedSale.plot()
# Out:
# <Axes: xlabel='day'>

# %%
#Branch with More Member vs Less Members
# branch with Highest Ratings vs Lowest Ratings

# %%
Members=sale25.groupby(['Member','State']).count()['Invoice ID']

# %%
Members
# Out:
# Member  State
# No      California        1
#         Nebraska          1
#         North Carolina    1
#         Washington        2
# Yes     California        8
#         Florida           2
#         Kentucky          2
#         Nebraska          1
#         North Carolina    1
#         Texas             2
#         Utah              3
#         Washington        1
# Name: Invoice ID, dtype: int64

# %%
Members.unstack(level=0).plot(kind='bar')
# Out:
# <Axes: xlabel='State'>

# %%
sale25.groupby(['State'])['Rating'].mean()
# Out:
# State
# California        3.666667
# Florida           1.500000
# Kentucky          4.500000
# Nebraska          3.000000
# North Carolina    3.000000
# Texas             3.000000
# Utah              4.000000
# Washington        3.333333
# Name: Rating, dtype: float64

# %%
rating=sale25.groupby(['State'])['Rating'].mean()

# %%
rating.plot(kind='bar')
# Out:
# <Axes: xlabel='State'>

# %%
# City with more female Sale
# Who spend more F or M
# Which Type spend more Memeber vs non menber
#Which product line sells more?
# Which product is popular among M & F?

# %%
FemaleShoppers=sale25.groupby(['City','Gender']).count()['Invoice ID']

# %%
FemaleShoppers
# Out:
# City             Gender
# Concord          F         1
#                  M         1
# Fort Lauderdale  F         1
#                  M         1
# Fort Worth       F         1
#                  M         1
# Fremont          F         1
#                  M         1
# Henderson        F         1
#                  M         1
# Los Angeles      F         4
#                  M         4
# Orem             F         1
# San Francisco    F         1
# Seattle          F         2
#                  M         1
# West Jordan      M         2
# Name: Invoice ID, dtype: int64

# %%
FemaleShoppers.unstack(level=0).plot(kind='bar')
# Out:
# <Axes: xlabel='Gender'>

# %%
FemaleSpend=sale25.groupby('Gender')['Total'].sum()

# %%
FemaleSpend
# Out:
# Gender
# F    3178
# M    1275
# Name: Total, dtype: int64

# %%
FemaleSpend.plot(kind='bar')
# Out:
# <Axes: xlabel='Gender'>

# %%
MemberHighsale=sale25.groupby(['City','Member']).count()['Invoice ID']

# %%
MemberHighsale
# Out:
# City             Member
# Concord          No        1
#                  Yes       1
# Fort Lauderdale  Yes       2
# Fort Worth       Yes       2
# Fremont          No        1
#                  Yes       1
# Henderson        Yes       2
# Los Angeles      No        1
#                  Yes       7
# Orem             Yes       1
# San Francisco    Yes       1
# Seattle          No        2
#                  Yes       1
# West Jordan      Yes       2
# Name: Invoice ID, dtype: int64

# %%
MemberHighsale.plot(kind='bar')
# Out:
# <Axes: xlabel='City,Member'>

# %%
MemberSpend=sale25.groupby('Member')['Total'].sum()

# %%
MemberSpend
# Out:
# Member
# No      831
# Yes    3622
# Name: Total, dtype: int64

# %%
MemberSpend.plot(kind='bar')
# Out:
# <Axes: xlabel='Member'>

# %%
ProductCount=sale25.groupby('Category')['Total'].sum()

# %%
ProductCount
# Out:
# Category
# Furniture           932
# Office Supplies    2672
# Technology          849
# Name: Total, dtype: int64

# %%
ProductCount.plot(kind='bar')
# Out:
# <Axes: xlabel='Category'>

# %%
ProductGenderBasedCount=sale25.groupby(['Category','Gender'])['Total'].sum()

# %%
ProductGenderBasedCount
# Out:
# Category         Gender
# Furniture        F          451
#                  M          481
# Office Supplies  F         2183
#                  M          489
# Technology       F          544
#                  M          305
# Name: Total, dtype: int64

# %%
ProductGenderBasedCount.unstack(level=0).plot(kind='bar')
# Out:
# <Axes: xlabel='Gender'>

# %%
sale25['Month']=pd.to_datetime(sale25['Order Date']).dt.month
# Out:
# C:\Users\divya.sunil\AppData\Local\Temp\ipykernel_7688\3871426499.py:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   sale25['Month']=pd.to_datetime(sale25['Order Date']).dt.month

# %%
sale25
# Out:
#     Row ID      Invoice ID  Order Date Gender       Customer Name  \
# 0        1  CA-2016-152156  18/05/2024      M         Claire Gute
# 1        2  CA-2016-152156  18/05/2024      F         Claire Gute
# 2        3  CA-2016-138688  18/05/2024      M     Darrin Van Huff
# 3        4  US-2015-108966  18/05/2024      M      Sean O'Donnell
# 4        5  US-2015-108966  18/05/2024      F      Sean O'Donnell
# 5        6  CA-2014-115812  18/05/2024      M     Brosina Hoffman
# 6        7  CA-2014-115812  18/05/2024      F     Brosina Hoffman
# 7        8  CA-2014-115812  18/05/2024      M     Brosina Hoffman
# 8        9  CA-2014-115812  30/05/2024      F     Brosina Hoffman
# 9       10  CA-2014-115812  30/05/2024      F     Brosina Hoffman
# 10      11  CA-2014-115812  30/05/2024      F     Brosina Hoffman
# 11      12  CA-2014-115812  30/05/2024      M     Brosina Hoffman
# 12      13  CA-2017-114412  30/05/2024      M        Andrew Allen
# ...

# %%
salebasedonmonth=sale25.groupby('Month')['Total'].sum()

# %%
salebasedonmonth
# Out:
# Month
# 5    2446
# 6    2007
# Name: Total, dtype: int64

# %%
salebasedonmonth.plot(kind='bar')
# Out:
# <Axes: xlabel='Month'>
