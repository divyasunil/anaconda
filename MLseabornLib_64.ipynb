# %%
import pandas as pd

# %%
data=pd.read_csv("saleList.csv")

# %%
data.head()
# Out:
#    Row ID      Invoice ID Order Date Gender    Customer Name    Segment  \
# 0       1  CA-2016-152156     08-Nov      M      Claire Gute   Consumer
# 1       2  CA-2016-152156     08-Nov      M      Claire Gute   Consumer
# 2       3  CA-2016-138688     12-Jun      M  Darrin Van Huff  Corporate
# 3       4  US-2015-108966     11-Oct      M   Sean O'Donnell   Consumer
# 4       5  US-2015-108966     11-Oct      F   Sean O'Donnell   Consumer
#
#               City       State Member Region         Category Sub-Category  \
# 0        Henderson    Kentucky    Yes  South        Furniture    Bookcases
# 1        Henderson    Kentucky    Yes  South        Furniture       Chairs
# 2      Los Angeles  California    Yes   West  Office Supplies       Labels
# 3  Fort Lauderdale     Florida    Yes  South        Furniture       Tables
# 4  Fort Lauderdale     Florida    Yes  South  Office Supplies      Storage
#
#       Price  Quantity  Total  Rating Payment
# ...

# %%
import seaborn as sns

# %%
sns.distplot(data.Rating)
# Out:
# C:\Users\divya.sunil\AppData\Local\Temp\ipykernel_1648\1936153260.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data.Rating)
# C:\Users\divya.sunil\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Rating', ylabel='Density'>

# %%
sns.distplot(data.Rating,kde=False)
# Out:
# C:\Users\divya.sunil\AppData\Local\Temp\ipykernel_1648\3343839720.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data.Rating,kde=False)
# <Axes: xlabel='Rating'>

# %%
help(sns.distplot)
# Out:
# Help on function distplot in module seaborn.distributions:
#
# distplot(a=None, bins=None, hist=True, kde=True, rug=False, fit=None, hist_kws=None, kde_kws=None, rug_kws=None, fit_kws=None, color=None, vertical=False, norm_hist=False, axlabel=None, label=None, ax=None, x=None)
#     DEPRECATED
#
#     This function has been deprecated and will be removed in seaborn v0.14.0.
#     It has been replaced by :func:`histplot` and :func:`displot`, two functions
#     with a modern API and many more capabilities.
#
#     For a guide to updating, please see this notebook:
#
#     https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751

# %%
sns.distplot(data.Rating,kde=False,color="red")
# Out:
# C:\Users\divya.sunil\AppData\Local\Temp\ipykernel_1648\1222598582.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data.Rating,kde=False,color="red")
# <Axes: xlabel='Rating'>

# %%
data['OfferPrice']=data['Price'] - (data['Price']*0.5)

# %%
data.head()
# Out:
#    Row ID      Invoice ID Order Date Gender    Customer Name    Segment  \
# 0       1  CA-2016-152156     08-Nov      M      Claire Gute   Consumer
# 1       2  CA-2016-152156     08-Nov      M      Claire Gute   Consumer
# 2       3  CA-2016-138688     12-Jun      M  Darrin Van Huff  Corporate
# 3       4  US-2015-108966     11-Oct      M   Sean O'Donnell   Consumer
# 4       5  US-2015-108966     11-Oct      F   Sean O'Donnell   Consumer
#
#               City       State Member Region         Category Sub-Category  \
# 0        Henderson    Kentucky    Yes  South        Furniture    Bookcases
# 1        Henderson    Kentucky    Yes  South        Furniture       Chairs
# 2      Los Angeles  California    Yes   West  Office Supplies       Labels
# 3  Fort Lauderdale     Florida    Yes  South        Furniture       Tables
# 4  Fort Lauderdale     Florida    Yes  South  Office Supplies      Storage
#
#       Price  Quantity  Total  Rating Payment  OfferPrice
# ...

# %%
sns.distplot(data.OfferPrice,kde=False,color="red")
# Out:
# C:\Users\divya.sunil\AppData\Local\Temp\ipykernel_1648\1324878072.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data.OfferPrice,kde=False,color="red")
# <Axes: xlabel='OfferPrice'>

# %%
iris = sns.load_dataset("iris")

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
sns.jointplot(x='sepal_length',y='sepal_width',data=iris)
# Out:
# C:\Users\divya.sunil\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\divya.sunil\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.pairplot(iris)
# Out:
# C:\Users\divya.sunil\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\divya.sunil\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\divya.sunil\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
sns.jointplot(x='petal_length',y='petal_width',data=iris)
# Out:
# C:\Users\divya.sunil\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\divya.sunil\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.pairplot(iris)
# Out:
# C:\Users\divya.sunil\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\divya.sunil\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\divya.sunil\AppData\Local\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...
