# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
data=pd.read_csv("housesale.csv")

# %%
data.head()
# Out:
#    price  resid_area  air_qual  dist1  dist2  dist3  dist4  teachers  \
# 0   24.0       32.31     0.589      2      2      2    2.0        24
# 1   21.6       37.07     0.532      4      2      3    3.0        24
# 2   34.7       37.07     0.425      3      2      1    1.0        24
# 3   33.4       37.07     0.485      3      2      3    3.0        24
# 4   36.9       37.07     0.564      3      3      3    3.0        24
#
#    poor_prop airport  n_hos_beds  n_hot_rooms waterbody  rainfall bus_ter  \
# 0        4.5      No       18.30       11.120     River        23      No
# 1        9.2      No       17.84       12.178      Lake        42     Yes
# 2        5.6      No       17.37       12.200       NaN        39      No
# 3        7.2      No        8.60       10.200      Lake        56      No
# 4        4.5      No        8.60       10.740      Lake        45     Yes
#
#     parks  Sold
# 0  0.0500     0
# 1  0.0469     1
# 2  0.0438     0
# 3  0.0407     0
# 4  0.0376     0

# %%
data.describe()
# Out:
#             price  resid_area    air_qual       dist1       dist2       dist3  \
# count  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# mean    23.733000   36.886000    0.457596    3.040000    2.420000    2.510000
# std      6.841363    1.584873    0.174682    0.723627    0.496045    1.029808
# min     12.500000   32.310000    0.045400    2.000000    2.000000    1.000000
# 25%     18.600000   37.070000    0.425000    3.000000    2.000000    2.000000
# 50%     22.400000   37.070000    0.532000    3.000000    2.000000    3.000000
# 75%     26.900000   38.140000    0.564000    4.000000    3.000000    3.000000
# max     36.900000   38.140000    0.589000    5.000000    3.000000    6.000000
#
#             dist4   teachers  poor_prop  n_hos_beds  n_hot_rooms    rainfall  \
# count  100.000000  100.00000  100.00000   92.000000   100.000000  100.000000
# mean     2.737279   20.98000    5.43800    5.546522    11.571310   43.120000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        100 non-null    float64
#  1   resid_area   100 non-null    float64
#  2   air_qual     100 non-null    float64
#  3   dist1        100 non-null    int64
#  4   dist2        100 non-null    int64
#  5   dist3        100 non-null    int64
#  6   dist4        100 non-null    float64
#  7   teachers     100 non-null    int64
#  8   poor_prop    100 non-null    float64
#  9   airport      100 non-null    object
#  10  n_hos_beds   92 non-null     float64
#  11  n_hot_rooms  100 non-null    float64
#  12  waterbody    86 non-null     object
#  13  rainfall     100 non-null    int64
#  14  bus_ter      100 non-null    object
#  15  parks        100 non-null    float64
#  16  Sold         100 non-null    int64
# dtypes: float64(8), int64(6), object(3)
# memory usage: 13.4+ KB

# %%
data.n_hos_beds=data.n_hos_beds.fillna(data.n_hos_beds.mean())

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        100 non-null    float64
#  1   resid_area   100 non-null    float64
#  2   air_qual     100 non-null    float64
#  3   dist1        100 non-null    int64
#  4   dist2        100 non-null    int64
#  5   dist3        100 non-null    int64
#  6   dist4        100 non-null    float64
#  7   teachers     100 non-null    int64
#  8   poor_prop    100 non-null    float64
#  9   airport      100 non-null    object
#  10  n_hos_beds   100 non-null    float64
#  11  n_hot_rooms  100 non-null    float64
#  12  waterbody    86 non-null     object
#  13  rainfall     100 non-null    int64
#  14  bus_ter      100 non-null    object
#  15  parks        100 non-null    float64
#  16  Sold         100 non-null    int64
# dtypes: float64(8), int64(6), object(3)
# memory usage: 13.4+ KB

# %%
data.waterbody=data.waterbody.fillna("No Data")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        100 non-null    float64
#  1   resid_area   100 non-null    float64
#  2   air_qual     100 non-null    float64
#  3   dist1        100 non-null    int64
#  4   dist2        100 non-null    int64
#  5   dist3        100 non-null    int64
#  6   dist4        100 non-null    float64
#  7   teachers     100 non-null    int64
#  8   poor_prop    100 non-null    float64
#  9   airport      100 non-null    object
#  10  n_hos_beds   100 non-null    float64
#  11  n_hot_rooms  100 non-null    float64
#  12  waterbody    100 non-null    object
#  13  rainfall     100 non-null    int64
#  14  bus_ter      100 non-null    object
#  15  parks        100 non-null    float64
#  16  Sold         100 non-null    int64
# dtypes: float64(8), int64(6), object(3)
# memory usage: 13.4+ KB

# %%
movie=pd.read_csv("HollywoodMovies.csv")

# %%
movie.describe()
# Out:
#        RottenTomatoes  AudienceScore  TheatersOpenWeek  OpeningWeekend  \
# count      913.000000     907.000000        949.000000      969.000000
# mean        51.707558      61.271224       2495.246575       20.620826
# std         26.821268      16.602457       1164.223356       25.338689
# min          0.000000      19.000000          1.000000        0.010000
# 25%         28.000000      49.000000       2054.000000        5.300000
# 50%         52.000000      61.000000       2798.000000       13.150000
# 75%         75.000000      74.000000       3285.000000       26.200000
# max         99.000000      96.000000       4468.000000      207.440000
#
#        BOAvgOpenWeekend  DomesticGross  ForeignGross   WorldGross      Budget  \
# count        945.000000     970.000000    876.000000   914.000000  897.000000
# mean        8562.593651      68.162544    101.237419   169.009945   56.117168
# std        10645.135565      80.409969    155.987696   227.744380   53.755914
# ...

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 970 entries, 0 to 969
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Movie             970 non-null    object
#  1   LeadStudio        961 non-null    object
#  2   RottenTomatoes    913 non-null    float64
#  3   AudienceScore     907 non-null    float64
#  4   Story             641 non-null    object
#  5   Genre             691 non-null    object
#  6   TheatersOpenWeek  949 non-null    float64
#  7   OpeningWeekend    969 non-null    float64
#  8   BOAvgOpenWeekend  945 non-null    float64
#  9   DomesticGross     970 non-null    float64
#  10  ForeignGross      876 non-null    float64
#  11  WorldGross        914 non-null    float64
#  12  Budget            897 non-null    float64
#  13  Profitability     896 non-null    float64
#  14  OpenProfit        895 non-null    float64
#  15  Year              970 non-null    int64
# ...

# %%
movie.ForeignGross=movie.ForeignGross.fillna(movie.ForeignGross.mean())

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 970 entries, 0 to 969
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Movie             970 non-null    object
#  1   LeadStudio        961 non-null    object
#  2   RottenTomatoes    913 non-null    float64
#  3   AudienceScore     907 non-null    float64
#  4   Story             641 non-null    object
#  5   Genre             691 non-null    object
#  6   TheatersOpenWeek  949 non-null    float64
#  7   OpeningWeekend    969 non-null    float64
#  8   BOAvgOpenWeekend  945 non-null    float64
#  9   DomesticGross     970 non-null    float64
#  10  ForeignGross      970 non-null    float64
#  11  WorldGross        914 non-null    float64
#  12  Budget            897 non-null    float64
#  13  Profitability     896 non-null    float64
#  14  OpenProfit        895 non-null    float64
#  15  Year              970 non-null    int64
# ...
